# %%
import pandas as pd
import seaborn as sns

sns.set_theme(color_codes=True)

# %%
train = pd.read_csv("./train_ctrUa4K.csv")
train.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
test = pd.read_csv("./test_lAUu6dG.csv")
test.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# 3             NaN         Urban
# 4             1.0         Urban

# %%
missing = train.isnull().sum() * 100 / train.shape[0]
missing[missing > 0].sort_values(ascending=False)
# Out:
# Credit_History      8.143322
# Self_Employed       5.211726
# LoanAmount          3.583062
# Dependents          2.442997
# Loan_Amount_Term    2.280130
# Gender              2.117264
# Married             0.488599
# dtype: float64

# %%
train['Credit_History'].fillna(0,inplace=True)
train['Self_Employed'].fillna('No',inplace=True)
train['LoanAmount'].fillna(0,inplace=True)
train['Dependents'].fillna('Other',inplace=True)
train['Loan_Amount_Term'].fillna(0,inplace=True)
train['Gender'].fillna('Other',inplace=True)
train['Married'].fillna('Other',inplace=True)
# Out:
# /tmp/ipython-input-1496799884.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train['Credit_History'].fillna(0,inplace=True)
# /tmp/ipython-input-1496799884.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train['Self_Employed'].fillna('No',inplace=True)
# /tmp/ipython-input-1496799884.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train['LoanAmount'].fillna(0,inplace=True)
# /tmp/ipython-input-1496799884.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train['Dependents'].fillna('Other',inplace=True)
# /tmp/ipython-input-1496799884.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train['Loan_Amount_Term'].fillna(0,inplace=True)
# /tmp/ipython-input-1496799884.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train['Gender'].fillna('Other',inplace=True)
# /tmp/ipython-input-1496799884.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train['Married'].fillna('Other',inplace=True)

# %%
missing = train.isnull().sum() * 100 / train.shape[0]
missing[missing > 0].sort_values(ascending=False)
# Out:
# Series([], dtype: float64)

# %%
sns.countplot(data=train,x='Loan_Status',hue ='Property_Area')
# Out:
# <Axes: xlabel='Loan_Status', ylabel='count'>

# %% [markdown]
# people living in suburban has high acceptable chance of loan status

# %%
sns.countplot(data=train,x='Loan_Status',hue ='Credit_History')
# Out:
# <Axes: xlabel='Loan_Status', ylabel='count'>

# %% [markdown]
# from this we can infer that, people with acceptable past credit history are most likely accepted in new loan.

# %%
sns.countplot(data=train,x='Loan_Status', hue='Loan_Amount_Term')
# Out:
# <Axes: xlabel='Loan_Status', ylabel='count'>

# %% [markdown]
# people with 360 month loan term are mostly to be accepted
